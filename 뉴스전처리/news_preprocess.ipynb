# %%
import pandas as pd
import re

# %%
data = pd.read_csv('./상폐기업뉴스.csv')
data
# Out:
#            기업                기사발행일                               기사제목  \
# 0      네이쳐글로벌  2010.10.01. 오전 9:23   [특징주] 네이쳐글로벌 상한가…"전 대표 횡령 확인 안돼"
# 1      네이쳐글로벌  2010.10.02. 오전 2:02           [코스닥 기업공시] (1일) 네이쳐글로벌 등
# 2      네이쳐글로벌  2010.09.28. 오후 4:29          네이쳐글로벌, 네비스탁측이 74만여주 장내매도
# 3      네이쳐글로벌  2010.09.16. 오전 9:23        [특징주] 네이쳐글로벌, 투자경고 지정 이후 약세
# 4      네이쳐글로벌  2010.09.14. 오후 4:21      네비스탁외 51인, 네이쳐글로벌 지분 1.26% 줄어
# ...       ...                  ...                                ...
# 10183   코썬바이오  2019.12.23. 오후 5:17                코썬바이오 불성실 공시법인 지정예고
# 10184   코썬바이오  2019.12.20. 오후 6:05                         코썬바이오 거래정지
# 10185   코썬바이오  2019.12.23. 오후 5:23           거래소, 코썬바이오 불성실 공시법인 지정예고
# 10186   코썬바이오  2020.02.07. 오전 9:58  인프라웨어, 최대주주는 누구?…‘호텔·바이오’ 사업 진출하나
# 10187   코썬바이오  2020.05.07. 오전 7:01                        기업공시[5월 6일]
#
#                                                   뉴스기사본문
# 0      비메모리 반도체 업체인 네이쳐글로벌이 전 대표 횡령 혐의에 대해 확인된 바 없다고 ...
# 1      ▲네이쳐글로벌=전 대표이사의 횡령,배임 및 가장납입이 확인되지 않음.\n\n▲세동=...
# 2      [이데일리 안재만 기자] 네비스탁은 특별관계자로 포함된 개인투자자들이 네이쳐글로벌(...
# 3      네이쳐글로벌이 투자경고 지정 소식에 이어 전환사채(CB) 물량 상장에 따른 수급 불...
# 4      [이데일리 유용무 기자] 네비스탁외 51인은 14일 신규 소액주주 의결권 규합 및 ...
# ...                                                  ...
# 10183  코썬바이오는 공시불이행으로 불성실 공시법인으로 지정예고 됐다고 23일 공시했다.\n...
# 10184  한국거래소는 코스닥 상장기업인 코썬바이오에 대해 12월 23일 하루동안 보통주에 대...
# 10185  [머니투데이 최태범 기자] 한국거래소 코스닥시장본부는 코썬바이오가 공시불이행에 따라...
# 10186  [아시아경제 장효원 기자] 소프트웨어 기업 인프라웨어의 최대주주가 변경된다. 새 최...
# 10187  [서울경제] <유가 증권>\n\n▲대림산업(000210)=삼호시트론시티·코크레인에스...
#
# [10188 rows x 4 columns]

# %%
data.groupby('기업').count()
# Out:
#         기사발행일  기사제목  뉴스기사본문
# 기업
# KCW        46    46      46
# 글로웍스       95    95      95
# 금강제강       10    10      10
# 나노트로닉스     35    35      35
# 나이스메탈     125   125     125
# ...       ...   ...     ...
# 한와이어리스    101   101     101
# 해피드림       92    92      92
# 핸디소프트      49    49      49
# 휴먼텍코리아     90    90      90
# 히스토스템      93    93      93
#
# [133 rows x 3 columns]

# %%
제거할기사제목 = ['증시 일정', '증시일정', '장마감후', '장 마감 후', '장마감공시', '증시 캘린더', '재송', '투자정보', \
    '코스닥 기업공시', '장중 주요', '코스닥 3분기 결산', '주요 뉴스 및 공시', '기업공시',' 기업 공시', '장 종료 후', \
        '특징주A/S', '주요 정보', '오전 공시', '투자정보', '기업 공시', '오늘의 메모', '재테크 캘린더', '추천주 정리', '희망복원 주식클리닉', \
        '\d{1,2}월 \d{1,2}일', '오늘의 주요 공시', '코스닥 공시', '코스닥 메모', '대박 공모주', '<표>', '오늘의 리포트', \
        '공략주', '주식상담소', '주식왕 따라잡기', '주식컨설팅', '\d{4} 증시', '춤추는 테마주', '개장시황', \
        '폭등신호 터진', '대폭등', '매드머니', '주담과 Q&A', '굿바이 \d{4}', '지금 당장 사라', '폭등주', \
        '\d{4}%', '김정일 사망', '종목대탐험', '종목신호등', 'VIP CLUB', '수급유망주', '기상도', '중소형주', \
        '국민주식고충처리반', '유망주', '머니Q', '시초가잡아라', '기관 Q&A', '부동산에 투자하려면', '베스트애널리스트', \
        '코스닥협회장 취임', '코스닥협회', '부동산에 투자하는 방법', '국가품질 경영대회', '증시일정', '머니Q', '추천종목', '티타임 공략주', \
        '수급유망주', '종목배틀', '\d{4} 증시 결산', '기업설명회', '종목신호등', 'VIP CLUB 추천주', '내일장 공략주 10선', '주간컨센서스동향', \
        '주담과 Q&A', '조회공시', '주가급등 사유', '관련株들', '게임株', '이시각 Up&Down', '장내 매도', '[인사]', '증시기상도', \
        '[재송]', '마감시황', '주식부자 속출', '교육주', '티타임 공략주', '\d{1,2}일 증권사 추천종목', '기업IR소식', '[승부주]']
제거제목리스트 = '|'.join(제거할기사제목)

# %%
data_unique = data.drop_duplicates(['뉴스기사본문'])
data_result = data_unique[~data_unique['기사제목'].str.contains(제거제목리스트, na=False, case=False)]
#data_result.to_csv('정상기업뉴스_.csv')
data_result
# Out:
#            기업                 기사발행일                                 기사제목  \
# 14     네이쳐글로벌   2010.08.16. 오후 5:21           네이쳐글로벌, 반기검토의견 "의견거절'…거래정지
# 19     네이쳐글로벌   2010.07.15. 오후 6:46             네이쳐글로벌 신용등급 `CC`로 두단계 하향
# 20     네이쳐글로벌   2010.06.03. 오후 5:06                  네이쳐글로벌, 20대 1 감자 실시
# 21     네이쳐글로벌  2010.05.24. 오전 10:41           <생생코스닥> 네이쳐글로벌 3거래일 연속 하한가
# 23     네이쳐글로벌   2010.05.18. 오후 1:23         네이쳐글로벌 "생수시장 진출 하반기 150억 계획"
# ...       ...                   ...                                  ...
# 10167   코썬바이오  2020.01.09. 오전 10:07  코썬바이오, 상한가 진입... 이평선 역배열 상황에서 반등 시도
# 10173   코썬바이오   2020.03.04. 오후 5:45                 코썬바이오, 거래소에 개선계획서 제출
# 10178   코썬바이오   2020.01.10. 오후 6:42                           코썬바이오 거래정지
# 10182   코썬바이오   2019.12.27. 오후 6:13               코썬바이오, 10억원 규모 유상증자 결정
# 10184   코썬바이오   2019.12.20. 오후 6:05                           코썬바이오 거래정지
#
#                                                   뉴스기사본문
# 14     네이쳐글로벌는 16일 반기 검토 의견이 "의견거절"로 관리종목 지정 사유가 발생했다...
# 19     [이데일리 이태호 기자] 네이쳐글로벌(088020)의 신용등급을 기존 `B-(부정적...
# 20     [이데일리 안재만 기자] 네이쳐글로벌(088020)은 20대 1 감자를 결의했다고 ...
# 21     네이쳐글로벌(088020)이 연 3거래일 연속 하한가를 기록하며 주가가 200원 선...
# 23     [머니투데이 김경원 기자]네이쳐글로벌(대표 박지우)은 대규모 생수회사를 자산양수도 ...
# ...                                                  ...
# 10167  [한국경제TV 라이온봇 기자]\n코썬바이오\n\n\n9일 오전 코썬바이오(20499...
# 10173  [이데일리 유현욱 기자] 한국거래소 코스닥시장본부는 4일 상장적격성 실질심사 대상으...
# 10178  한국거래소는 코스닥 상장기업인 코썬바이오에 대해 1월 13일부터 상장적격성 실질심사...
# 10182  [이데일리 김윤지 기자] 코썬바이오(204990)는 운영자금 10억원을 조달하기 위...
# 10184  한국거래소는 코스닥 상장기업인 코썬바이오에 대해 12월 23일 하루동안 보통주에 대...
#
# [2702 rows x 4 columns]

# %%
data_result.groupby('기업').count()['기사발행일'] < 10
# Out:
# 기업
# 경창산업       False
# 고영테크놀러지    False
# 광림         False
# 금화피에스시      True
# 나스미디어      False
#            ...
# 하이록코리아     False
# 한국정보통신      True
# 해성산업        True
# 홈캐스트        True
# 휴맥스        False
# Name: 기사발행일, Length: 108, dtype: bool

# %%
pattern1 = r'\([^)]*\)'
#pattern2 = r'\[[^)]*\]'
pattern2 = r"\[([^]]+)\]"

data_result['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_result['뉴스기사본문']]
data_result['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_result['뉴스기사본문전처리']]
data_result
data_result.to_csv('상폐기업뉴스전처리.csv', index=None)
# Out:
# C:\Users\dbswo\AppData\Local\Temp\ipykernel_11312\226564118.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_result['뉴스기사본문']]
# C:\Users\dbswo\AppData\Local\Temp\ipykernel_11312\226564118.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\dbswo\AppData\Local\Temp\ipykernel_11312\226564118.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\dbswo\AppData\Local\Temp\ipykernel_11312\226564118.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\dbswo\AppData\Local\Temp\ipykernel_11312\226564118.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_result['뉴스기사본문전처리']]
